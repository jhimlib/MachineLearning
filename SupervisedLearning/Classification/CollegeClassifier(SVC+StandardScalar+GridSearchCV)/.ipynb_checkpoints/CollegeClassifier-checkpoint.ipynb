# %%
#import necessary libraries
import pandas as pd

# %%
#load data
college = pd.read_csv("Dataset/College.csv")
college.head()
# Out:
#   Private  Apps  Accept  Enroll  Top10perc  Top25perc  F.Undergrad  \
# 0     Yes  1660    1232     721         23         52         2885
# 1     Yes  2186    1924     512         16         29         2683
# 2     Yes  1428    1097     336         22         50         1036
# 3     Yes   417     349     137         60         89          510
# 4     Yes   193     146      55         16         44          249
#
#    P.Undergrad  Outstate  Room.Board  Books  Personal  PhD  Terminal  \
# 0          537      7440        3300    450      2200   70        78
# 1         1227     12280        6450    750      1500   29        30
# 2           99     11250        3750    400      1165   53        66
# 3           63     12960        5450    450       875   92        97
# 4          869      7560        4120    800      1500   76        72
#
#    S.F.Ratio  perc.alumni  Expend  Grad.Rate
# 0       18.1           12    7041         60
# 1       12.2           16   10527         56
# ...

# %%
college.describe()
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# ...

# %%
college['Private'].value_counts()
# Out:
# Yes    565
# No     212
# Name: Private, dtype: int64

# %%
#set features and target
x=college.iloc[:,1:]
y=college.iloc[:,0]

# %%
#Use LabelEncoder to encode the target variable to numerical form
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()
y=encoder.fit_transform(y)

# %%
#Split the data such that 20% of the data is set aside for testing.
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=100)

# %% [markdown]
# <h3>Fit a linear SVM from scikit-learn and observe the accuracy.</h3>

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

svc_model=SVC()
svc_model.fit(x_train,y_train)
y_predict=svc_model.predict(x_test)

print(accuracy_score(y_test,y_predict))
# Out:
# 0.6858974358974359

# %% [markdown]
# <h3>Preprocess the data using StandardScalar and fit the same model again. Observe the change in accuracy.  </h3>

# %%
from sklearn.preprocessing import StandardScaler

scaler=StandardScaler()
x_scaled= scaler.fit_transform(x)

# %%
x_scale_train,x_scale_test,y_train,y_test=train_test_split(x_scaled,y,test_size=0.2,random_state=100)

# %%
svc_model=SVC()
svc_model.fit(x_scale_train,y_train)
y_predict=svc_model.predict(x_scale_test)

print(accuracy_score(y_test,y_predict))
# Out:
# 0.9294871794871795

# %% [markdown]
# <h3>Use scikit-learn’s gridsearch to select the best hyper-parameter for a non-linear SVM.</h3>

# %%
from sklearn.model_selection import GridSearchCV
import warnings
warnings.filterwarnings('ignore')
param_grid={'C':[0.1,1,10,100],'gamma':[1,0.1,0.01,0.001]}

grid=GridSearchCV(SVC(),param_grid,refit=True,verbose=2)
grid.fit(x_scale_train,y_train)
# Out:
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
# [CV] C=0.1, gamma=1 ..................................................
# [CV] ................................... C=0.1, gamma=1, total=   0.0s
# [CV] C=0.1, gamma=1 ..................................................
# [CV] ................................... C=0.1, gamma=1, total=   0.0s
# [CV] C=0.1, gamma=1 ..................................................
# [CV] ................................... C=0.1, gamma=1, total=   0.0s
# [CV] C=0.1, gamma=0.1 ................................................
# [CV] ................................. C=0.1, gamma=0.1, total=   0.0s
# [CV] C=0.1, gamma=0.1 ................................................
# [CV] ................................. C=0.1, gamma=0.1, total=   0.0s
# [CV] C=0.1, gamma=0.1 ................................................
# [CV] ................................. C=0.1, gamma=0.1, total=   0.0s
# ...

# %%
y_predict_grid=grid.predict(x_scale_test)

print(accuracy_score(y_test,y_predict_grid))
# Out:
# 0.9230769230769231

# %% [markdown]
# <h3>GridSearchCV on original dataset not scaled dataset</h3>

# %%
param_grid={'C':[0.1,1,10,100],'gamma':[1,0.1,0.01,0.001]}

grid=GridSearchCV(SVC(),param_grid,refit=True,verbose=2)
grid.fit(x_train,y_train)
# Out:
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
# [CV] C=0.1, gamma=1 ..................................................
# [CV] ................................... C=0.1, gamma=1, total=   0.0s
# [CV] C=0.1, gamma=1 ..................................................
# [CV] ................................... C=0.1, gamma=1, total=   0.0s
# [CV] C=0.1, gamma=1 ..................................................
# [CV] ................................... C=0.1, gamma=1, total=   0.0s
# [CV] C=0.1, gamma=0.1 ................................................
# [CV] ................................. C=0.1, gamma=0.1, total=   0.0s
# [CV] C=0.1, gamma=0.1 ................................................
# [CV] ................................. C=0.1, gamma=0.1, total=   0.1s
# [CV] C=0.1, gamma=0.1 ................................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# ...

# %%
y_predict_grid=grid.predict(x_test)

print(accuracy_score(y_test,y_predict_grid))
# Out:
# 0.6858974358974359

# %% [markdown]
# <h3>Identify the model with the best score and its parameters.</h3>

# %%
#SVC model  : 0.6858974358974359
#SVC model with StandardScaler model : 0.9294871794871795
#SVC model with StandardScaler + GridsearchCV model : 0.9230769230769231
#SVC model + GridsearchCV model : 0.6858974358974359
